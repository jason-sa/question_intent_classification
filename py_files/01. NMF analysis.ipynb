# %% [markdown]
# # NMF Analysis
#
# Performs a simple tf-idf of the question pairs and NMF dimension reduction to calculate cosine similarity of each question pair. The goal of the analysis is to see if the pairs labeled as duplicates have a distinctly different cosine similarity compared to those pairs marked as not duplicates.

# %%
# data manipulation
from utils import save, load
import pandas as pd
import numpy as np

# modeling
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from sklearn.metrics.pairwise import cosine_similarity

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'svg'
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline

# %%
X_train = load('X_train')
y_train = load('y_train')
train_df = pd.DataFrame(np.concatenate([X_train, y_train.reshape(-1, 1)], axis=1))
train_df = train_df.rename(columns={0:'id', 1:'question1', 2:'question2', 3:'is_duplicate'})
train_df.head()
# Out:
#   id                                          question1  \
# 0  0  What is the step by step guide to invest in sh...
# 1  1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2  2  How can I increase the speed of my internet co...
# 3  3  Why am I mentally very lonely? How can I solve...
# 4  4  Which one dissolve in water quikly sugar, salt...
#
#                                            question2 is_duplicate
# 0  What is the step by step guide to invest in sh...            0
# 1  What would happen if the Indian government sto...            0
# 2  How can Internet speed be increased by hacking...            0
# 3  Find the remainder when [math]23^{24}[/math] i...            0
# 4            Which fish would survive in salt water?            0

# %% [markdown]
# Let's make a stack of questions maintaining the `id` of the question pair.

# %%
question_df = train_df.loc[:, ['id', 'question1']]
question_df = question_df.append(train_df.loc[:,['id', 'question2']], sort=False)
question_df.loc[question_df['question1'].isna(), 'question1'] = question_df.loc[question_df['question1'].isna(), 'question2']
question_df = question_df.drop(columns='question2')
question_df = question_df.sort_values('id')
question_df.head(6)
# Out:
#   id                                          question1
# 0  0  What is the step by step guide to invest in sh...
# 0  0  What is the step by step guide to invest in sh...
# 1  1  What would happen if the Indian government sto...
# 1  1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2  2  How can I increase the speed of my internet co...
# 2  2  How can Internet speed be increased by hacking...

# %% [markdown]
# Let's now calcualte the tf-idf term matrix.

# %%
tf = TfidfVectorizer(stop_words='english', token_pattern='\\b[a-zA-Z0-9][a-zA-Z0-9]+\\b')

question_tf = tf.fit_transform(question_df['question1'])

# %%
# first 10 terms
tf.get_feature_names()[:10]
# Out:
# ['00',
#  '000',
#  '0000',
#  '000000',
#  '00000000',
#  '0000000000',
#  '0000001',
#  '00000074',
#  '0000021210',
#  '00001']

# %%
# last 10 terms
tf.get_feature_names()[-10:]
# Out:
# ['zygote',
#  'zygotene',
#  'zyl',
#  'zylber',
#  'zynga',
#  'zyrtec',
#  'zyzz',
#  'zz',
#  'zzz',
#  'zzzquil']

# %%
# total terms
len(tf.get_feature_names())
# Out:
# 74795

# %% [markdown]
# Lots of words, but some cleanup will probably needed given the numbers.
#
# Let's now reduce the 74,795 term matrix utilizing NMF.

# %%
def calc_NMF_sim(n_components, col_name, tf_df, df):
    nmf = NMF(n_components=n_components)

    nmf_topics = nmf.fit_transform(tf_df)

    odd_idx = [i for i in range(nmf_topics.shape[0]) if i % 2 == 1]
    even_idx = [i for i in range(nmf_topics.shape[0]) if i % 2 == 0]

    sim_list = [cosine_similarity(
                                    nmf_topics[odd_idx[i]].reshape(1,-1),
                                    nmf_topics[even_idx[i]].reshape(1,-1)
                )[0,0]
                for i in range(len(odd_idx))]

    df = pd.concat([df.sort_values('id'), pd.Series(sim_list)], axis=1)
    df = df.rename(columns={0:col_name})
    
    return df

# %%
train_df_cosine = calc_NMF_sim(5, 'cos_sim_5', question_tf, train_df.reset_index())
train_df_cosine = calc_NMF_sim(10, 'cos_sim_10', question_tf, train_df_cosine)
train_df_cosine = calc_NMF_sim(50, 'cos_sim_50', question_tf, train_df_cosine)
train_df_cosine = calc_NMF_sim(100, 'cos_sim_100', question_tf, train_df_cosine)

# %%
train_df_cosine.head()
# Out:
#    index id                                          question1  \
# 0      0  0  What is the step by step guide to invest in sh...
# 1      1  1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2      2  2  How can I increase the speed of my internet co...
# 3      3  3  Why am I mentally very lonely? How can I solve...
# 4      4  4  Which one dissolve in water quikly sugar, salt...
#
#                                            question2 is_duplicate  cos_sim_5  \
# 0  What is the step by step guide to invest in sh...            0   0.633264
# 1  What would happen if the Indian government sto...            0   0.862924
# 2  How can Internet speed be increased by hacking...            0   0.939746
# 3  Find the remainder when [math]23^{24}[/math] i...            0   0.844232
# 4            Which fish would survive in salt water?            0   0.993024
#
#    cos_sim_10  cos_sim_50  cos_sim_100
# 0    0.671246    0.214359     0.333102
# 1    0.297672    0.024921     0.039276
# 2    0.691180    0.523763     0.441854
# 3    0.461991    0.469578     0.940291
# 4    0.982065    0.960928     0.893077

# %% [markdown]
# We calcualted the cosine similarity for 5, 10, 50, and 100 dimensional dimensional NMF. Let's now plot the distribution for the duplicate pairs and not duplicate pairs. The goal is to see if there is a natural division based purely on the cosine similarity between the pair of questions.

# %% [markdown]
# ## This seems off!!!
#
# Need to figure out why there is so much overlap now. Let's ignore for now and see if the MVP model suffers the same.

# %%
cols = ['cos_sim_5', 'cos_sim_10', 'cos_sim_50', 'cos_sim_100']
plt.figure(figsize=(10,10))

for i in range(4):
    plt.subplot(2, 2, i+1)
    sns.kdeplot(train_df_cosine.loc[train_df_cosine['is_duplicate'] == 0, cols[i]], 
                 shade=True, 
                 label = 'No Intent',
                 color = 'red')
    sns.kdeplot(train_df_cosine.loc[train_df_cosine['is_duplicate'] == 1, cols[i]], 
                 shade=True,
                 label = 'Intent',
                 color = 'green')
    plt.title(cols[i])
    plt.ylim(top=25)

# plt.xlabel('cosine similarity')
# plt.ylabel('density')
plt.suptitle('KDE comparing pairs with intent and no intent')
;
# Out:
# ''

# %% [markdown]
# More of the duplicate pairs have a higher cosine similarity compared to the non-duplicate pairs. However, there is also significant overlap, which means finding the decision boundary will be difficult.

# %% [markdown]
# Let's take a look at the set of pairs marked as duplicates with a 0 cosine similarity with the NMF 100 transformation.

# %%
train_df_cosine[(train_df_cosine['is_duplicate'] == 1) & (train_df_cosine['cos_sim_100'] == 0)]
# Out:
#          index      id                                          question1  \
# 2672      2672    3526                              What does agape mean?
# 4353      4353    5745               How does a precision rectifier work?
# 7162      7162    9574                     What is human body made up of?
# 8493      8493   11337                             What does Netlogon do?
# 9324      9324   12463             How do I find out if I have a warrent?
# 9497      9497   12706                 How do you get a girl to like you?
# 12535    12535   16857                          How can you learn Hadoop?
# 14763    14763   19874  Why the language C++ is named so? Why was it n...
# 17462    17462   23456              How do you know if you have a cavity?
# 20600    20600   27647                How was the 90s different from now?
# 25187    25187   33763  What is racketeering and what are some example...
# 25357    25357   33986          Is it possible to get out of friendzoned?
# 28854    28854   38603                      How does RSA decryption work?
# 30364    30364   40604              In what ways do we enslave ourselves?
# 30922    30922   41345             What should I do to move to the U.S.A?
# 30980    30980   41426                  Where do you think Gendry is now?
# 32292    32292   43213         Can two people have the same fingerprints?
# 33352    33352   44629                                 Am I really alone?
# 33876    33876   45318                             What do historians do?
# 36495    36495   48815       What is the best way to learn AngularJS 2.0?
# 38945    38945   51974                                      How is 0! =1?
# 39567    39567   52814  What are good ways to decrease your calorie in...
# 41795    41795   55770  What is the difference between unicellular and...
# 42360    42360   56525  I have no interest in anything, what should I do?
# 46041    46041   61356                            What is best anecdotes?
# 48896    48896   65171                 How do you get a girl to like you?
# 49052    49052   65385                      How can you get over someone?
# 50736    50736   67651                          How do I move on in life?
# 53710    53710   71622                What does a business consultant do?
# 54591    54591   72812                        How can one be an optimist?
# ...        ...     ...                                                ...
# 253726  253726  338333        What should I do when I have nothing to do?
# 253808  253808  338447         How can I become a good conversationalist?
# 253889  253889  338551                                   Can 2+2 be five?
# 254314  254314  339101                    What is something you never do?
# 255792  255792  341059                                Can 2+2 be equal 5?
# 258521  258521  344748                What's the best way to find myself?
# 258814  258814  345131                         Why do men have mustaches?
# 260211  260211  346981             What are some harsh realities of life?
# 261096  261096  348201         What is the best way to describe yourself?
# 261561  261561  348827                         How do I get a girlfriend?
# 261625  261625  348903                                     What is a now?
# 263215  263215  351045                 What do you mean by globalization?
# 263435  263435  351337                               How is popcorn made?
# 265399  265399  353972                           What we use autocad for?
# 271099  271099  361482              What is the best way to find someone?
# 271688  271688  362259                               Why does 0! Equal 1?
# 273216  273216  364275     Which one is better, Kopaja or Metromini? Why?
# 273236  273236  364301                            Do people like Quartzy?
# 273888  273888  365172                            What do copywriters do?
# 285814  285814  381049  What are the differences between a runway and ...
# 286567  286567  382057                  Which one's best, 1D or Maroon 5?
# 289278  289278  385661     What are the best replacements for chia seeds?
# 289773  289773  386308                        What's mean of sapiosexual?
# 293981  293981  391932                    How do I ask questions on here?
# 294237  294237  392272                       Is Lexus better than Toyota?
# 294918  294918  393180                            What is VMware Use for?
# 294948  294948  393215               Do multivitamins really help people?
# 296827  296827  395737                                Can we prove 0! =1?
# 299805  299805  399724                  How does Asana compare to Trello?
# 302919  302919  403931  What is the difference between a unicellular a...
#
#                                                 question2 is_duplicate  \
# 2672                                What is agape (love)?            1
# 4353                      Why we use precision rectifier?            1
# 7162                                What are you made of?            1
# 8493                           What is NetLogon used for?            1
# 9324                   How do I find out about a warrent?            1
# 9497              What are some ways to get a girlfriend?            1
# 12535         What is essential to start learning Hadoop?            1
# 14763                                Why C++ and not ++C?            1
# 17462        How can you tell if you have a tooth cavity?            1
# 20600   What is the difference between life in the 90s...            1
# 25187                        What does racketeering mean?            1
# 25357                How do I get out of the friend zone?            1
# 28854                     Can you answer my RSA question?            1
# 30364                   Why do people enslave themselves?            1
# 30922                         How can I move to the U.S.?            1
# 30980                             Did Gendry stop rowing?            1
# 32292   Why don't any two persons in the world have th...            1
# 33352                                         Am I alone?            1
# 33876                           What does a historian do?            1
# 36495   What are some good ways of learning AngularJS ...            1
# 38945                               Why is 0! equal to 1?            1
# 39567   What is the best way to reduce your calorie in...            1
# 41795   What are the different characteristics of unic...            1
# 42360   What should I do when I don't have interest in...            1
# 46041                What are some interesting anecdotes?            1
# 48896                  How can I get a girlfriend easily?            1
# 49052                Can you get over someone completely?            1
# 50736                               How does one move on?            1
# 53710                             What do consultants do?            1
# 54591                How does one become more optimistic?            1
# ...                                                   ...          ...
# 253726          What do you do when you've nothing to do?            1
# 253808           How can I be the best conversationalist?            1
# 253889                       Can two plus two equal five?            1
# 254314             What is something you have never done?            1
# 255792                                   Can 2+2 be five?            1
# 258521                                 How I find myself?            1
# 258814                      Why do people have mustaches?            1
# 260211       What are some harsh realities of this world?            1
# 261096                      How do you describe yourself?            1
# 261561               How do I get a girl to like me back?            1
# 261625                                       What is now?            1
# 263215              What is the meaning of globalization?            1
# 263435                           How are Popcorners made?            1
# 265399                         What is AutodCAD used for?            1
# 271099                            How can I find someone?            1
# 271688                                      How is 0! =1?            1
# 273216  What is the difference between a Kopaja and a ...            1
# 273236            What do scientists think about Quartzy?            1
# 273888                         What does a copywriter do?            1
# 285814     What is the difference b/w runway and taxiway?            1
# 286567        Which is better, One Direction or Maroon 5?            1
# 289278     What are some good substitutes for chia seeds?            1
# 289773                What is the meaning of sapiosexual?            1
# 293981                                How do I post here?            1
# 294237                      Should I buy Lexus or Toyota?            1
# 294918                               What does VMware do?            1
# 294948                             Do multivitamins work?            1
# 296827                                      How is 0! =1?            1
# 299805                    What's better, Asana or Trello?            1
# 302919  What are the different characteristics of unic...            1
#
#         cos_sim_5  cos_sim_10  cos_sim_50  cos_sim_100
# 2672     0.394222    0.074720    0.000000          0.0
# 4353     0.366223    0.339545    0.000000          0.0
# 7162     0.000000    0.000000    0.000000          0.0
# 8493     0.559942    0.251427    0.010065          0.0
# 9324     0.000000    0.000000    0.000000          0.0
# 9497     0.062028    0.113867    0.037448          0.0
# 12535    0.825164    0.984763    0.000073          0.0
# 14763    0.000000    0.000000    0.000000          0.0
# 17462    0.673022    0.304215    0.000000          0.0
# 20600    0.828017    0.060438    0.218934          0.0
# 25187    0.067743    0.093820    0.011195          0.0
# 25357    0.332219    0.734545    0.096964          0.0
# 28854    0.000000    0.000000    0.000000          0.0
# 30364    0.000000    0.000000    0.000000          0.0
# 30922    0.000000    0.000000    0.000000          0.0
# 30980    0.999631    0.637862    0.097700          0.0
# 32292    0.646014    0.797980    0.020849          0.0
# 33352    0.000000    0.000000    0.000000          0.0
# 33876    0.000000    0.000000    0.000000          0.0
# 36495    0.466696    0.810655    0.000000          0.0
# 38945    0.000000    0.000000    0.000000          0.0
# 39567    0.326982    0.260532    0.004475          0.0
# 41795    0.930034    0.649573    0.295783          0.0
# 42360    0.000000    0.000000    0.000000          0.0
# 46041    0.028902    0.000000    0.000000          0.0
# 48896    0.100328    0.176622    0.189905          0.0
# 49052    0.000000    0.000000    0.000000          0.0
# 50736    0.000000    0.000000    0.000000          0.0
# 53710    0.042508    0.078795    0.003540          0.0
# 54591    0.027954    0.000000    0.000000          0.0
# ...           ...         ...         ...          ...
# 253726   0.000000    0.000000    0.000000          0.0
# 253808   0.013363    0.000000    0.000000          0.0
# 253889   0.000000    0.000000    0.000000          0.0
# 254314   0.000000    0.000000    0.000000          0.0
# 255792   0.000000    0.000000    0.000000          0.0
# 258521   0.000000    0.000000    0.000000          0.0
# 258814   0.337074    0.078743    0.000000          0.0
# 260211   0.965838    0.024432    0.000000          0.0
# 261096   0.000000    0.000000    0.000000          0.0
# 261561   0.740715    0.799557    0.532314          0.0
# 261625   0.000000    0.000000    0.000000          0.0
# 263215   0.000000    0.000000    0.002618          0.0
# 263435   0.000000    0.000000    0.000000          0.0
# 265399   0.663222    0.644459    0.378051          0.0
# 271099   0.000000    0.000000    0.000000          0.0
# 271688   0.000000    0.000000    0.000000          0.0
# 273216   0.978682    0.147137    0.000000          0.0
# 273236   0.524099    0.299687    0.000000          0.0
# 273888   0.000000    0.000000    0.000000          0.0
# 285814   0.979327    0.894847    0.274083          0.0
# 286567   0.000000    0.000000    0.000000          0.0
# 289278   0.017462    0.000000    0.000000          0.0
# 289773   0.000000    0.000000    0.001166          0.0
# 293981   0.999248    0.995475    0.000000          0.0
# 294237   0.362613    0.025842    0.000000          0.0
# 294918   0.360666    0.333502    0.000000          0.0
# 294948   0.173993    0.034404    0.196935          0.0
# 296827   0.000000    0.000000    0.000000          0.0
# 299805   0.000000    0.009957    0.000000          0.0
# 302919   0.930034    0.649573    0.295783          0.0
#
# [171 rows x 9 columns]

# %% [markdown]
# The first example is very confusing. This may be a result of the tf-idf calculation with default parameters is incorrect, or the cosine similarity is not the best metric. The next step would be to build a classification model using NMF or LDA topics for the pair of questions to predict whether or not the pair has the same intent.
