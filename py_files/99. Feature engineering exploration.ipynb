# %% [markdown]
# ## Word Vec Similarity

# %%
import utils
import pandas as pd
import numpy as np

from sklearn import metrics

# %%
X_train = utils.load('X_train')
X_train_lemma = utils.load('X_train_lemma')

# %%
X_train_stack = utils.stack_questions(X_train)

# %%
vecs = []
cos_sim = []
counter = 1
for doc in utils.nlp.pipe(X_train_stack[:10], disable=['parser', 'ner']):
    vecs.append(np.array(doc.vector).reshape(1, -1))
    if counter % 2 == 0:
        cos_sim.append(metrics.pairwise.cosine_similarity(vecs[0], vecs[1])[0,0])
        vecs = []
    counter += 1
cos_sim
# Out:
# [0.98668426, 0.9249996, 0.9290682, 0.73074234, 0.846616]

# %%
X_train_lemma = [str(x) for x in X_train_lemma]

# %%
vecs = []
cos_sim = []
counter = 1
for doc in utils.nlp.pipe(X_train_lemma[:10], disable=['parser', 'ner']):
    vecs.append(np.array(doc.vector).reshape(1, -1))
    if counter % 2 == 0:
        cos_sim.append(metrics.pairwise.cosine_similarity(vecs[0], vecs[1])[0,0])
        vecs = []
    counter += 1
cos_sim
# Out:
# [0.9682379, 0.8167546, 0.8931898, 0.55023444, 0.7400342]

# %%
X_train_lemma[0]
# Out:
# 'step step guide invest share market india'

# %%
from scipy.spatial.distance import pdist

# %% [markdown]
# ## Generate min/max/avg distance features between words.
#
# Can use the below to find the min/max/average distance between words for each sentence.

# %%
def calc_min_max_avg_distance(v, metric):
    dist = pdist(v, metric=metric)
    return [np.min(dist), np.max(dist), np.mean(dist)]

# %%
dist = []
for doc in utils.nlp.pipe(X_train_stack[7:8], disable=['parser', 'ner']):
    print([tok for tok in doc])
    vecs = [tok.vector for tok in doc if tok.vector.sum() != 0] # accounts for white space vector of 0
#     print(vecs[4])
    dist.append(calc_min_max_avg_distance(vecs, 'euclidean'))
    dist.append(calc_min_max_avg_distance(vecs, 'cosine'))
    dist.append(calc_min_max_avg_distance(vecs, 'cityblock'))

    
dist
# Out:
# [Find, the, remainder, when, [, math]23^{24}[/math, ], is, divided, by, 24,23, ?]
# [[2.4431328502651244, 8.243298300698449, 6.451411427066599],
#  [0.0811163002913935, 0.9673326969514745, 0.7217991310274229],
#  [33.83734008832835, 110.19580763683189, 86.96829082302811]]

# %%
# latex tags should be stripped!!
import re

# replace math tags with blank spaces
math_re = re.compile('\[math.*math\]')
X_train_stack_math = [math_re.sub('', x) for x in X_train_stack]

# remove punctuations
import string
punctuations = re.compile(f'[{re.escape(string.punctuation)}]')

num_re = re.compile('[0-9]')

# X_train_stack_math = [num_re.sub('', x) for x in X_train_stack_math]
X_train_stack_math = [punctuations.sub('',x) for x in X_train_stack_math]
X_train_stack_math = [re.sub(r"""\w*\d\w*""", '', x) for x in X_train_stack_math]

X_train_stack_math[7]
# Out:
# 'Find the remainder when  is divided by '

# %%
alphanumeric = lambda x: re.sub(r"""\w*\d\w*""", ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())

# %%
for x in X_train_stack_math:
    if '[' in x:
        print(x)
#         print(math_re.sub('', x))
        print()
# Out:
# How do I get my website on the first page on Google [Search for specific Keyword] ?
#
# [Late 2015 / Early 2016] Why does the United Kingdom want to leave the European Union? Why do some people there want to quit the EU?
#
# [Before Brexit vote] What are the pros and cons of Britain exiting/staying in the EU?
#
# [SPOILER] How big of a shock was it that Darth Vader was Luke's father when it was first revealed?
#
# [Force Awakens Spoilers]: When Kylo Ren killed his father, why did it take around 25 seconds for Chewbacca and co to react violently?
#
# What is the solution of this:- [{√ (√5+2) +√ (√5-2)} /√ (√5+1)]-√ (3-2√2)?
#
# [Late 2015 / Early 2016] Why does the United Kingdom want to leave the European Union? Why do some people there want to quit the EU?
#
# At the end of Rogue One, how did the rebels feel when they saw [SPOILER]?
#
# [SPOILERS] Why did Mary save Sherlock from the bullet in the first episode of season four of Sherlock?
#
# How do I solve √ [5+2(√6)]?
#
# Game of Thrones Season 5 Episode 8 (Hardhome): [spoiler] How many wildlings are left after the white walkers' attack?
#
# How can you prove that pH= -log [H+]?
#
# How do I prepare for the GATE in 3–6 months? What are the recommended study strategies ? [ EC, CS, EE, ME, AE, Civil, CHE, Phy, Math]
#
# What's the remainder when [(2) ³] ³¹ is divided by 7?
#
# I will be ordering these capsules [ Http://www.healthkart.com/sv/nutrex-lipo-6-black-hers-uc/SP-30132?navKey=VRNT-57196&itracker=w:searchresults%7C;p:1%7C;c:Lipo%206%7C;e:24%7Cfalse%7C? ] for weight loss. Do they have any side effects?
#
# Homework Question: I have this formula [10 = x - (1.29 + 4.99% of x)]. How do I calculate x?
#
# How does Cooper in Interstellar end up in a tesseract? [SPOILER]
#
# Are your Python scripts failing like this: urllib2.URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed?
#
# Why are names shown as [Last name, First name]?
#
# [Spoilers] In Harry Potter and the cursed child book, What happened to Draco's wife?
#
# What is the difference between () and [] in Python?
#
# [Spoiler] Does the name VALAK appears as separate letters in the bookshelf as well when Warren scribbles it?
#
# How do I overload the [] operator in C++?
#
# [SPOILER] In Godzilla, Ken Watanabe's character disapproves of the military's plan. What exactly does he have in mind as an alternative strategy?
#
# [SPOILER] Why was a main character in Star Wars killed off? Is there a chance of him coming back?
#
# How should I prepare for 10th std. board exams [g.s.e.b]?
#
# How much can I earn monthly from a tech blog based on my Angular, Node, MongoDB, and Express [MEAN] interests? What things do I need to remember to make more money from my blog and attract more visitors?
#
# How do the teachings, learning, followership and/or fellowship of Christianity project, propel and propagate the master-slave ideology [un,sub] consciously?
#
# How do the teachings, learning, followership and/or fellowship of Hinduism, project, propel and propagate the master-slave ideology [un,sub] consciously?
#
# [SPOLIERS]Are all the Children of the Forest dead?
#
# [SPOILER] In Game of Thrones Season 6, are there any Children alive after episode 5?
#
# Who shot [X] in The Walking Dead season 5, episode 8?
#
# What's the difference between *p [5] and (*p) [5]?
#
# 24*7 Call @@ [{ (1-8777- 7889-69)}] MSN Tech support Number?
#
# How do I overload the [] operator in C++?
#
# How can overloading of operator [] be done in C++?
#
# What are the examples of elastic goods [15 atleast]?
#
# Which Study material should I buy to complete FRM L1 2017’s May session? BT or Schweser [Pick the best one]
#
# If Jon Snow was the son of [...], why did Ned Stark not tell Catelyn Stark about it?
#
# What is difference between String args [] or String [] args?
#
# What is the difference between string args [] and string [] args in Java?
#
# What does each term in "public static void main(String[] args)" mean?
#
# Why do we use static in "public static void main (String args[]) in Java?
#
# How can I score 100% in 12th [CBSE PCM]?
#
# Is Hinduism neither a religion nor the ways of [after]life?
#
# What ratio of [Pb2+] to [Sn2+] is needed to reverse the following cell reaction?
#
# Why is [(-1) ^(1/2)] ^3 not equal to [(-1) ^3] ^(1/2)?
#
# Why isn’t India adopting the policy [it used against Pakistan (Balochistan) ]against China( South China Sea) to get into NSG?
#
# How do I get my website on the first page on Google [Search for specific Keyword] ?
#
# Does FMS [Faculty of Management Studies, New Delhi] accept only the CAT or the GMAT for admission into its MBA course?
#
# How do I prove that [1+(k+1) / (1! *2) +(k+1) (k+2) / (2! *2^2) +...] is (1/2) ^-(k+1)?
#
# How can I design an op - amp circuit that can solve the equation y = x^3 +double integral of 4xdx + [(e^(-3x) +1)/(e^(2x) +2)] +5?
#
# If [?
#
# [SPOILERS] Who is the "Cursed Child" in Harry Potter and the Cursed Child?
#
# [SPOILERS] In Harry Potter and the Cursed Child why didn’t Draco use the time-turner he had anytime before?
#
# Anyone working as Associate IT Operations - Level 12 [16] Accenture?
#
# Why has [Co Cl4] 2- dsp2 and not sp3 hybridation?
#
# What is the limit of [1/x] as x approaches 0?
#
# [Spoiler Alert] How will Luffy defeat Big Mom or how he will escape her territory? Is there any possibility of the first Yonko fight in this arc?
#
# What does ' [*]' mean?
#
# What does ' [*]' mean?
#
# What is the Laplace transform of t* [(0.5) ^t] *u(t)?
#
# Why hasnt michelle Obama [Michael] been outes as a man?
#
# Is there a clean [without expletives] version of the Hitchhiker's Guide to the Galaxy?
#
# [06x08] Is it possible that the Waif killed Arya and took her face?
#
# I'm an experienced professional in my field [business and design]. Books and courses help too little on learning. How can I improve myself?
#
# I'm an experienced professional in my field [business and design]. Books and courses help me too little on learning. How can I improve myself?
#
# Is it true that this insect can cause a skin disease like the one shown? [See details below]
#
# [SPOILER] What was the significance of the dinner table scene in The Walking Dead Season 7 Episode 1?
#
# Is a question in Quora limited to 150 [text] characters and question details to 300 characters?
#
# Is a question in Quora limited to 150 [text] characters and question details to 300 characters?
#
# How many marshmallows will I get [on average] in one handful of Lucky Charms cereal?
#
# What books do you recommend for first year engineering students [SPITians]?
#
# Breaking Bad (TV series): Why did Walt force his son, Walter Jr., to drink during the party [Season 2 Episode 10] celebrating his shrinking tumor?
#
# For a general number N, how many enumerations are there of numbers from the set [1...N] that sum to N?
#
# What is your review of La ʾilaha Ha Il Allah -Quran[7:65] There Is No God but Allah?
#
# What does each term in "public static void main(String[] args)" mean?
#
# On what basis does NASA recruit its employees [specifically Indian employees]?
#
# How can I write a program to print hello on C without using () [] {} <> in the program?
#
# [SPOILERS] Who is the "Cursed Child" in Harry Potter and the Cursed Child?
#
# How can I write a program to print hello on C without using () [] {} <> in the program?
#
# Why do women when they talk to their girlfriends about their date or a new boyfriend often say things like, "He's not very tall/he's a little bald/he's a little skinny... but [insert something positive]." Is it because women have a very precise idea of how their prince charming should be and feel like they have to justify why they chose a man who doesn't correspond 100% to that image?
#
# [UPSC] : Which paper of political science & international ralations should be studied first as optional subject?
#
# Why do people ask [how are you? ] when they really don't want to know?
#
# How do I prepare for the GATE in 3–6 months? What are the recommended study strategies ? [ EC, CS, EE, ME, AE, Civil, CHE, Phy, Math]
#
# What does this line mean in javascript " let {path: tempPath, originalFilename} = files.imageFile [0];"?
#
# A coin that comes up heads with probability p is continually flipped until the pattern T T H appears. Let X denote the number of flips needed until the pattern is observed.  What is the expected value of X  i.e. E [X]?
#
# Star Wars: The Force Awakens (2015 movie): [Spoilers] Who are Rey's parents? Is she Luke's daughter?
#
# [Spoiler] Toward the end of the movie, there was a silent close-up of Fletcher saying something to Andrew. What was he saying?
#
# [Before Brexit vote] What are the pros and cons of Britain exiting/staying in the EU?
#
# [SPOILER ALERT] Why was Melisandre (Red Lady) staring at Jon Snow in castle black while they were burning the men?
#
# [Spoiler] In The Force Awakens, why would the last trained Jedi in the galaxy choose to go into hiding when he is so clearly needed?
#
# [Spoiler] Why did Luke go looking for the first Jedi temple?
#
# In machine learning algorithms, why is sigmoid function used primarily and not functions like tanh(x)? In tanhx for eg. seem to split y-axis evenly and flatten out fast as x approaches +/- infinity. The range being: sigmoid [0-1] and tanh(x) [-1,1].
#
# What are all the possible rational zeros for f(x) =6x^3+6x^2-15x-2 If f(x) =x^3+4 and g(x) =x+3, find [g*f] (2)?
#
# What are all the possible rational zeros for f(x) =x^3+8x+6 What is 3 [f(x+2)] if f(x) =x^3+2x^2-4?
#
# [pre-election] Will President Obama pardon Hillary Clinton before leaving office?
#
# How does Cooper in Interstellar end up in a tesseract? [SPOILER]
#
# [Spoiler] Interstellar movie: How did Cooper entered/came up in the Tesseract and how/why the Tesseract vanished after some time?
#
# Def my_fun(i): values = [] values.append(i) return values my_fun(5) print (my_fun(3)) why getting only [3] and not [5,3]?
#
# [SPOILER] In The Walking Dead Season 6 Finale, who did Negan kill?
#
# What is the difference between [code ]n++[/code] and [code ]n=n+1[/code] in [code]printf()[/code] function in C?
#
# What is the difference between [code]=[/code] and [code]==[/code] in C++?
#
# Iron Man 3 (2013 movie): [Spoiler alert] Why does Stark need a truck battery to recharge the Mk. 42 while, for the previous armors, the Arc reactor did the job?
#
# Eset Antivirus! 1877]! [778]! [8969! Helpline Tollfree Number?
#
# Kaspersky Antivirus! 1877]! [778]! [8969! Helpline Tollfree Number?
#
# SPOILER: Is [X] dead at the end of Catching Fire?
#
# [pre-election] Will President Obama pardon Hillary Clinton before leaving office?
#
# The Walking Dead Season 6 Episode 2 (JSS): [SPOILER] Where did Enid disappear to?
#
# The Walking Dead Season 6 Episode 2 (JSS): [SPOILER] Is Enid one of the wolves?
#
# When is a leasee responsible for property taxes in Illinois (not Chicago) [see comments]?
#
# Is it GOOD to shift from Blogger [BlogSpot] to WordPress?
#
# Is Hinduism neither a religion nor the ways of [after]life?
#
# [SPOILER] What do Walking Dead fans think of Rick and Michonne's relationship?
#
# [FIXED] Why can't I change the video quality in the Android YouTube app?
#
# How do I prepare for the GATE in 3–6 months? What are the recommended study strategies ? [ EC, CS, EE, ME, AE, Civil, CHE, Phy, Math]
#
# Reddit (website): What does it mean when [deleted] appears where a commenter's name should go?
#
# What is the limit of [1/x] as x approaches 0?
#
# What is answer of this program code int a[infinity] for (i=0; i<infinity; i++) {scanf(“%d”, a[i]);}
#
# What are your predictions for season 6, episode 8 of Game of Thrones ["No One"]?
#
# What new paradigms do you think may be significant in the future of interactive computing? [
#
# Which is the free video editing software that I can use to create this kind of videos? [see the link in detail]
#
# [SPOILER] What is your review of The Walking Dead Season 7 Episode 1?
#
# What came first? Pi [22/7] or integration?
#
# [SPOILERS] What will Tony Stark do after Captain America: Civil War? Will he kill Bucky, and/or continue with the Avengers?
#
# Why is [(-1) ^(1/2)] ^3 not equal to [(-1) ^3] ^(1/2)?
#
# Why does a pulsar [fastest rotating objects] can only be seen when its beam is pointing towards Earth?
#
# Why does Sherlock say Detective Bell is intelligent? [Elementary]
#
# [SPOILER] What is your review of The Walking Dead Season 7 Episode 1?
#
# What is the difference between [code]int* const ptr[/code] and [code]int const* ptr[/code]?
#
# Iron Man 3 (2013 movie): [Spoiler alert] Why does Stark need a truck battery to recharge the Mk. 42 while, for the previous armors, the Arc reactor did the job?
#
# What is [n:] in Python?
#
# What is your review of Mulk Raj Anand [Indian Writer In English]?
#
# [UPSC] : Which paper of political science & international ralations should be studied first as optional subject?
#
# [(x+1) (x+2) …(x+n)] /x = summation (ar/x+r). Find ar?
#
# [removed]
#
# [SPOILER] In The Walking Dead Season 6 Finale, who did Negan kill?
#
# What is the difference between () and [] in Python?
#
# [SPOILER]: Could Jon Snow be the prince that was promised?
#
# [removed]
#
# The Walking Dead Season 6 Episode 12 (Not Tomorrow Yet): [SPOILER] Was it a mistake for Rick's group to attack Negan's compound? What could they have done better or instead?
#
# The Walking Dead Season 6 Episode 12 (Not Tomorrow Yet): [SPOILER] Why exactly did Rick's group attack Negan's compound?
#
# Why do ducks do this? [Warning: NSFW]
#
# What does ' [*]' mean?
#
# Assume a firm has a Cobb-Douglas production function Y=L^0.5 K^0.5 (^=at the power of). Assume [w] wage= $1, [r] rental=$2 and price of output [p] =$5 and firm has linear cost function. What is the marginal product of capital (MPK) and the marginal product of labor (MPL) for the firm?
#
# How could Kickass torrent owner Artem Vaulin [the man in News and should be] transacting through an iCloud account which logs your IP address?
#
# Why is talking about my fetish online easier? =[
#
# [SPOILER] What caused the “thing” revealed at the ending of La La Land?
#
# What is m+n if [45+29* (sqrt(2)] ^(1/3) =m+n* (sqrt(2))?
#
# Why is "myself [name]" grammatically incorrect?
#
# [Spoiler] Why did Lex Luthor cut himself and give blood in the Krypton spaceship? What was the point of that?
#
# South American warrior tribes vs European Viking warriors [men & women], which one will win? PART TWO View ChangesThank
#
# How much do you earn via your Android app [paid or free]?
#
# Should I test my IQ? [Full question in comments]
#
# Which spelling for [தமிழ்] is perfectly suitable in English (Tamil or Thamizh)?
#
# Which "D" is overdrive [D] or D?
#
# How do I write a ruby program to display the Armstrong numbers in an array (with the array being; Numbers = [123,124,153,370,234,23,45]?
#
# Is the book Who Is Muhammad? [Book] By Jafar Subhani (Author) the best ever book about prophet muhammad?
#
#
# [Spoiler] Did Cobb enter into reality in the end of the Inception movie?
#
# Is a question in Quora limited to 150 [text] characters and question details to 300 characters?
#
# [September 2016] If Trump wins the election who would you blame for this?
#
# [Spoilers]What do you think about Harry Potter and the Cursed Child?
#
# Find the second-order Taylor series approximation for F(x) about the point x = [0 0] T?
#
# What is the difference between (*m) [5] and *m [5] in C programming language?
#
# WHY India IS BUYING APACHE HELICOPTER FROM USA INSTEAD of MAKING light COMBAT HELICOPTER [LCH] FROM HINDUSTAN AERONOTICS LIMITED [HAL]?
#
# What are your predictions for season 6, episode 8 of Game of Thrones ["No One"]?
#
# [SPOILER] What did Gregor Clegane do to Septa Unella in the episode Winds of Winter (S06E10)?
#
# What does the "String[ ] args" in a Java main method actually mean?
#
# How much do you earn via your Android app [paid or free]?
#
# What is the output for in main {char *ptr="hello"; ptr [0] ='m'; printf ("%s", *s);}?
#
# Which articles/script(ure)s/poems/prose did Lord/God Shiv[a] write?
#
# [pre-election] Will President Obama pardon Hillary Clinton before leaving office?
#
# Can I use this number //* [[1800*251*4919]] *// Belkin Router Techical Support Number Belkin ROUTER phone numbers?
#
# How do I prepare for the GATE in 3–6 months? What are the recommended study strategies ? [ EC, CS, EE, ME, AE, Civil, CHE, Phy, Math]
#
# How do I integrate of [1/ (1+ (tanx) ^1/2)] form pi/6 to pi/3?
#
# Hey….can anybody tell me about their experience with RTI [Right To Information] and some basics about it?
#
# [September 2016] If Trump wins the election who would you blame for this?
#
# Barring Turkey [which is a Muslim majority country] in Europe which was the biggest minority group [religion, region, race etc wise] in 1920s and 30s. If it is not Jews or gypsies why were they only targeted in the Holocaust?
#
# Can we write ssc [10th] exams without joining school in andhrapradesh for now?
#
# How normal is it for straight women to question their sexuality [for a long time]?
#
# Output of for (I=0;I<cards; I++) {deck [I].face=suit [I%faces]?
#
# Rolles theorem x^x+6 [-6 , 0]?
#
# Breaking Bad (TV series): Why did Walt force his son, Walter Jr., to drink during the party [Season 2 Episode 10] celebrating his shrinking tumor?
#
# How can I show to the world that I [a 1 3-years old boy] has discovered a new thing?
#
# What is the output for in main {char *ptr="hello"; ptr [0] ='m'; printf ("%s", *s);}?
#
# How best could I evaluate n, if the constant term in the expansion of [x²-(1/x]^n is 15?
#
# How can overloading of operator [] be done in C++?
#
# Where are the communising [not communalist] organizing branches of women within the country?
#
# Where are the communising [not communalist] organizing branches of minorities within the country?
#
# [Spoilers] In Harry Potter and the cursed child book, What happened to Draco's wife?
#
# When a function h(x) is bounded, how do I prove that the limit of [f(x) *h(x)] as x->a equals zero?
#
# Star Wars: The Force Awakens (2015 movie): [Spoilers] Who are Rey's parents? Is she Luke's daughter?
#
# What does SC:\Users\InQUES>python ex1.py: \Python27\python.exe: can't openfile'ex1.py' [Errno2] No such file or director mean in the windows powershell?
#
# What are the ways  to separate this matrix into two matrix mathematically? for eg. m=[-1 0 1;-2 0 2;-1 0 1]  into a=[1 2 1] b=[-1 0 1] so m=a'*b;
#
# How can I solve this equation: tan[1/2 cos(inverse) (√5/3)] = ?
#
# How do you think growing up [much of your life] without a father affected you? If you could say one thing to your father today, what would it be?
#
# What is difference between String args [] or String [] args?
#
# What are the tenets of [a] democracy?
#
# Why is enough historical research not done on the Rayar [Thanjavur Maratha Kingdom] community of South India?
#
# Is a question in Quora limited to 150 [text] characters and question details to 300 characters?
#
# Why is talking about my fetish online easier? =[
#
# Did Tony Stark [spoiler] at the end of Iron Man 3?
#
# Molecular weight of U [236]?
#
# [SPOILERS] Who is the "Cursed Child" in Harry Potter and the Cursed Child?
#
# What is the difference between a = {} and a = [] in Ruby?
#
# What is 3-{3-3 [3-(3-3)]} /3 =?
#
# What is your review of Mahatma Gandhi And His Myths: Civil Disobedience, Nonviolence, And Satyagraha In The Real World (Plus Why It'S 'Gandhi,' Not 'Ghandi') [Book] By Mark Shepard (author)?
#
# Two natural number r,s are drawn one at a time, without replacement from the set S {1,2,3…, n}. Find P [r≤p\s≤p], where p€ (belongs to) S?
#
# What does ' [*]' mean?
#
# The Dark Knight Rises (2012 movie): What evidence was there that Talia did or did not have romantic feelings for [character]?
#
# Where are the communising [not communalist] organizing branches of women within the country?
#
# What is the meaning of [x]<1?
#
# Is there a difference between int a [10] and int (*a) [10]?
#
# [Spoilers]What do you think about Harry Potter and the Cursed Child?
#
# [SPOILERS] What is the plot summary of Harry Potter and the Cursed Child (2016 play)?
#
# [SPOILERS] Who is the "Cursed Child" in Harry Potter and the Cursed Child?
#
# [Spoilers]What do you think about Harry Potter and the Cursed Child?
#
# What is the minimized form of this logic expression: F (A, B, C, D) = [] (0,3,4,5,6,7,11,13,14,15)?
#
# How do you change the font size of a [code]WKInterfaceLabel[/code] programmatically?
#
# [SPOILER] In Fantastic Beasts and Where to Find Them, why did Gellert Grindelwald hunt the Obscurial?
#
# [SPOILER] How did Albus and Scorpius get to Godric's Hollow without wands or Muggle money?
#
# What does int *(a) [20] mean?
#
# What is your review of Islam & Jihad: Prejudice Versus Reality [Book] By Abdul Gafoor Abdul Majeed Noorani?
#
# Can I use this number //* [[1800*251*4919]] *// Belkin Router Techical Support Number Belkin ROUTER phone numbers?
#
# What does each term in "public static void main(String[] args)" mean?
#
# [Spoiler] What are predictions of where we will see Arya in Game of Thrones season 7?
#
# [SPOILER] Why was a main character in Star Wars killed off? Is there a chance of him coming back?
#
# Support_Number""@@ [1] * [800] * [251] * [4919] @@"" microsoft windows 7 technical support phone number?
#
# What is - [- (-7)]?
#
# What is the meaning behind [The Duck Song]?
#
# [Star Wars VII Spoiler] Having Leia and Han for parents and Luke Skywalker as an uncle, how could Kylo Ren have grown up idolizing Darth Vader?
#
# What is the continuity of f in [-2,2] and nature of each discontinuity if f(x) = x+ {-x} +[x]?
#
# What are the best "the [blank] is real" phrases?
#
# How does 25-55+ [85+65] = 5!
#
# How do I get my website on the first page on Google [Search for specific Keyword] ?
#
# [Spoiler] In the Westworld season 1 finale, who was Dolores actually meeting with all along?
#
# How do I graph X=[X]?
#
# Begin Again (2013 movie): Why did Keira Knightley's character decide to [spoiler] at the end?
#
# [SPOILER] How big of a shock was it that Darth Vader was Luke's father when it was first revealed?
#
# Can I wear casual shirt [untucked] with penny loafers?
#
# Do education restrict (blind) thoughts, beliefs, transgressions, [re]actions and activity?
#
# How do education restrict (blind) thoughts, beliefs, transgressions, [re]actions and activity?
#
# [UPSC] : Which paper of political science & international ralations should be studied first as optional subject?
#
# How can I know [z] or [s] when a word ends with a letter “s”?
#
# If a reaction has a solid product and two aqueous reactants, is the Ksp equal to 1/ [reactants]?
#
# How does 25-55+ [85+65] = 5!
#
# [READ DESCRIPTION] I always get pissed off, when I see, that something changes in my world (YouTube, etc.) — how can I deal more easily with that?
#
# Why do people ask [how are you? ] when they really don't want to know?
#
# How do I Simplify the following matrices:
# 1. -5 [-7 0 0 5]; 2. 3 [6 4 5 -5 3 1]?
#
# [SPOILER ALERT] At the end of Fight Club, why did Tyler Durden die?
#
# What is hcf of polynomials   [explain]?
#
# What is the functional differences between ' - ', ` -`, " -", ( - ), and [ - ] in Bash?
#
# What is the difference between public class and public static void main (string[]args)?
#
# Can we use a private or non static variable in public static void main (String args[])?
#
# Can I use this number //* [[1800*251*4919]] *// Belkin Router Techical Support Number Belkin ROUTER phone numbers?
#
# What is meaning of int &a = b[0] [0]; in C++?
#
# [Spoilers]What do you think about Harry Potter and the Cursed Child?
#
# If the domain of f(x) is [6,12] and f(6) =f(12), then what is the domain of g(x) =f(x)-f(x+2)?
#
# What should we learn from the movie Oh My God! [OMG]?
#
# Urjent ## [{(1) (877) (778) (8969)}] ## ROADRUNNER password Recovery number?
#
# How much do you earn via your Android app [paid or free]?
#
# How do the teachings, learning, followership and/or fellowship of Islam project, propel and propagate the master-slave ideology [un,sub] consciously?
#
# How do the teachings, learning, followership and/or fellowship of Hinduism, project, propel and propagate the master-slave ideology [un,sub] consciously?
#
# In which of the following pair is the second particle listed larger than the first? [K, GA ] [Pb, C] [Be, Br-] [Li, Li+]
#
# What is the difference between [ ] and [[ ]] in R?
#
# Why are there so many trolls on Quora who ask stupid health questions like: How do I remove [harmless thing] from my body?
#
# How do I prepare for the GATE in 3–6 months? What are the recommended study strategies ? [ EC, CS, EE, ME, AE, Civil, CHE, Phy, Math]
#
# [Spoiler] How did Cooper know that Brand was in love with Edmund?
#
# What does each term in "public static void main(String[] args)" mean?
#
# Let D be a 2x2 matrix with D = [1 -4; x 2] with the ';' meaning a new row in the matrix. For which value(s) of x is rank(D) = 2?
#
# What is your review of The Poona Pact [An Agreement Between Dr. Babasaheb Ambedkar And Mahatma Gandhi Signed On 24 September 1932]?
#
# If 2 [x/2] ^2+3 [x/8] =20, then x lies in the smallest interval [a,b). What is the value of b-a?
#
# [SPOILER] In The Walking Dead Season 6 Finale, who did Negan kill?
#
# How do you know that [NiCl4] 2- has tetrahedral geometry whereas [Ni(CN) 4] 2- has square planar geometry?

# %%
doc = utils.nlp(X_train_lemma[0], disable=['parser', 'ner'])
len(doc.i)
# Out:
